# %% [markdown]
# <a href="https://colab.research.google.com/github/danielaterra/shape-based-CervicalCellsClassifier/blob/main/CRIC_morfo_featureSelection_without_hierarc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Seleção de features (coeficientes) EFD para núcleo + citoplasma (base CRIC)

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         226G   23G  203G  11% /
# tmpfs            64M     0   64M   0% /dev
# shm              17G   24K   17G   1% /dev/shm
# /dev/root       2.0G  1.1G  910M  54% /sbin/docker-init
# tmpfs            18G   48K   18G   1% /var/colab
# /dev/sda1       233G   41G  193G  18% /etc/hosts
# tmpfs            18G     0   18G   0% /proc/acpi
# tmpfs            18G     0   18G   0% /proc/scsi
# tmpfs            18G     0   18G   0% /sys/firmware
# drive            15G  788M   15G   6% /content/drive

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %%
import os
print(os.name)

import platform
print("Architecture: ", platform.machine())
print("SO: ", platform.system())
print("Python version: ", platform.python_version())
# Out:
# posix
# Architecture:  x86_64
# SO:  Linux
# Python version:  3.8.16

# %%
# !pip install pyefd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyefd
#   Downloading pyefd-1.6.0-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.8/dist-packages (from pyefd) (1.21.6)
# Installing collected packages: pyefd
# Successfully installed pyefd-1.6.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
sys.path.insert(0,"/content/drive/MyDrive/shape_based_CRIC_Hclassifier")

# %%
import numpy as np
import pandas as pd 
from math import sqrt
import os
import sys
import csv
from collections import Counter
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow 
from skimage import morphology, measure
from skimage.draw import polygon, polygon_perimeter
from scipy.spatial.distance import cdist
from scipy.stats import kurtosis

import pyefd
from pyefd import elliptic_fourier_descriptors, normalize_efd

from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn import feature_selection as fs

from datetime import datetime

# pay attention to capitalization below!
from spFSR import SpFSR
from imblearn.over_sampling import SMOTE, ADASYN, SVMSMOTE, BorderlineSMOTE

from itertools import cycle
from random import randint
from random import sample

import xgboost as xgb 

import functions, shapeFeatures

# %%
Bethesda_classes = {'Normal':0, 'ASC-US':1, 'ASC-H':2, 'LSIL':3,'HSIL':4, 'Invasive Carcinoma':5} 
Bethesda_idx_classes = {0: 'Normal', 1:'ASC-US', 2:'ASC-H', 3:'LSIL',4: 'HSIL', 5:'Invasive Carcinoma'}

# %%
len(functions.list_all_features(20)), len(functions.list_all_nucleus_features(20)), len(functions.list_all_cyto_features(20)), len(functions.list_all_EFD_features(20))
# Out:
# (200, 98, 98, 154)

# %% [markdown]
# ### Lê arquivo (features):

# %%
N_EFD_COEFFS = 20

# %%
df = pd.read_csv('/content/drive/MyDrive/shape_based_CRIC_Hclassifier/dataCRIC.csv', sep='|', header=0)
df = shapeFeatures.normalize_dataset(df, n_efd_coeffs= N_EFD_COEFFS)

# %%
df
# Out:
#       image_id  cell_id     areaN    eccenN   extentN     periN    maxAxN  \
# 0          1.0  14796.0  0.007403  0.606414  0.842276  0.031326  0.036711
# 1          1.0  14797.0  0.009371  0.541484  0.808102  0.035945  0.039493
# 2          1.0  14798.0  0.007275  0.313794  0.884418  0.029457  0.025365
# 3          1.0  14799.0  0.010570  0.489270  0.778201  0.040199  0.040900
# 4          1.0  14801.0  0.009115  0.296366  0.842276  0.036826  0.031283
# ...        ...      ...       ...       ...       ...       ...       ...
# 3228     399.0  11539.0  0.028927  0.838629  0.579720  0.094256  0.134656
# 3229     399.0  11540.0  0.025333  0.874227  0.645532  0.094611  0.135676
# 3230     400.0  11535.0  0.017031  0.910741  0.390863  0.092280  0.136377
# 3231     400.0  11536.0  0.020797  0.949322  0.528816  0.105709  0.169029
# 3232     400.0  11537.0  0.025076  0.822746  0.749691  0.090669  0.120781
#
#         minAxN   compacN    circuN  ...    efdC73    efdC74    efdC75  \
# 0     0.083827  0.024126  0.863522  ...  0.156532  0.321490  0.859931
# 1     0.095649  0.018763  0.891071  ...  0.150931  0.317850  0.859539
# 2     0.097062  0.018895  0.890378  ...  0.153458  0.315454  0.861978
# 3     0.103428  0.021001  0.879403  ...  0.157254  0.319562  0.860312
# 4     0.106376  0.024456  0.861871  ...  0.147193  0.314554  0.860292
# ...        ...       ...       ...  ...       ...       ...       ...
# 3228  0.118369  0.041270  0.784196  ...  0.152113  0.318217  0.859606
# 3229  0.100778  0.064959  0.692461  ...  0.150010  0.322108  0.859366
# 3230  0.078990  0.131860  0.507358  ...  0.153944  0.319972  0.860379
# 3231  0.065965  0.137720  0.494794  ...  0.151898  0.320620  0.859608
# 3232  0.114052  0.055801  0.725789  ...  0.143373  0.318753  0.868085
#
#         efdC76    efdC77  ratio_NC  ratio_NC_per  ratio_NC_hArea  \
# 0     0.382225  0.302311  0.017236      0.115646        0.016730
# 1     0.369221  0.299938  0.010656      0.089517        0.010168
# 2     0.367980  0.302076  0.007400      0.073961        0.006897
# 3     0.382943  0.303682  0.028309      0.154784        0.027752
# 4     0.359672  0.300094  0.021569      0.129992        0.020738
# ...        ...       ...       ...           ...             ...
# 3228  0.370535  0.299400  0.206211      0.149094        0.085315
# 3229  0.375599  0.300755  0.245537      0.247086        0.136756
# 3230  0.372458  0.303245  0.191508      0.471092        0.188343
# 3231  0.370771  0.299599  0.111823      0.078186        0.023058
# 3232  0.362569  0.279162  0.448090      0.346307        0.181780
#
#       nucleus_position  bethesda
# 0             0.099098       0.0
# 1             0.121456       0.0
# 2             0.043773       0.0
# 3             0.128927       0.0
# 4             0.069245       0.0
# ...                ...       ...
# 3228          1.943974       5.0
# 3229          0.916374       5.0
# 3230          0.326252       5.0
# 3231          3.177247       5.0
# 3232          0.653692       5.0
#
# [3233 rows x 203 columns]

# %%
# Separa dados por classe:
data_normal = df[df['bethesda'] == 0].copy()
data_normal.set_index((i for i in range(data_normal.shape[0])), inplace=True)

data_ascus = df[df['bethesda'] == 1].copy()
data_ascus.set_index((i for i in range(data_ascus.shape[0])), inplace=True)

data_asch = df[df['bethesda'] == 2].copy()
data_asch.set_index((i for i in range(data_asch.shape[0])), inplace=True)

data_lsil = df[df['bethesda'] == 3].copy()
data_lsil.set_index((i for i in range(data_lsil.shape[0])), inplace=True)

data_hsil = df[df['bethesda'] == 4].copy()
data_hsil.set_index((i for i in range(data_hsil.shape[0])), inplace=True)

data_car = df[df['bethesda'] == 5].copy()
data_car.set_index((i for i in range(data_car.shape[0])), inplace=True)

print("--- Totais por classe --- ")               
print("Normal...: ", data_normal.values.shape[0])               
print("ASC-Us...: ", data_ascus.values.shape[0])               
print("ASC-H....: ", data_asch.values.shape[0])               
print("LSIL.....: ", data_lsil.values.shape[0])               
print("HSIL.....: ", data_hsil.values.shape[0])               
print("Carcinoma: ", data_car.values.shape[0])
# Out:
# --- Totais por classe ---
# Normal...:  862
# ASC-Us...:  286
# ASC-H....:  536
# LSIL.....:  598
# HSIL.....:  874
# Carcinoma:  77

# %% [markdown]
# #### Gera dataframes: dados (data), classes (target) e Ids (image/cell)

# %%
# Monta base (data, target, image/cells ids)
data, target, image_cells_ids= functions.get_database_data_targe_ids(data_normal, data_ascus, 
                       data_lsil, data_asch, data_hsil,data_car,
                       functions.list_all_features(N_EFD_COEFFS))

# %%
data
# Out:
#          areaN    eccenN   extentN     periN    maxAxN    minAxN   compacN  \
# 0     0.007403  0.606414  0.842276  0.031326  0.036711  0.083827  0.024126
# 1     0.009371  0.541484  0.808102  0.035945  0.039493  0.095649  0.018763
# 2     0.007275  0.313794  0.884418  0.029457  0.025365  0.097062  0.018895
# 3     0.010570  0.489270  0.778201  0.040199  0.040900  0.103428  0.021001
# 4     0.009115  0.296366  0.842276  0.036826  0.031283  0.106376  0.024456
# ...        ...       ...       ...       ...       ...       ...       ...
# 3228  0.028927  0.838629  0.579720  0.094256  0.134656  0.118369  0.041270
# 3229  0.025333  0.874227  0.645532  0.094611  0.135676  0.100778  0.064959
# 3230  0.017031  0.910741  0.390863  0.092280  0.136377  0.078990  0.131860
# 3231  0.020797  0.949322  0.528816  0.105709  0.169029  0.065965  0.137720
# 3232  0.025076  0.822746  0.749691  0.090669  0.120781  0.114052  0.055801
#
#         circuN   convexN    hAreaN  ...    efdC72    efdC73    efdC74  \
# 0     0.863522  0.770499  0.007010  ...  0.412223  0.156532  0.321490
# 1     0.891071  0.798761  0.008657  ...  0.411473  0.150931  0.317850
# 2     0.890378  0.789171  0.006857  ...  0.413300  0.153458  0.315454
# 3     0.879403  0.749075  0.009960  ...  0.410648  0.157254  0.319562
# 4     0.861871  0.762196  0.008313  ...  0.417445  0.147193  0.314554
# ...        ...       ...       ...  ...       ...       ...       ...
# 3228  0.784196  0.807286  0.026930  ...  0.414090  0.152113  0.318217
# 3229  0.692461  0.831169  0.024210  ...  0.412031  0.150010  0.322108
# 3230  0.507358  0.771387  0.020188  ...  0.411450  0.153944  0.319972
# 3231  0.494794  0.761416  0.021758  ...  0.414575  0.151898  0.320620
# 3232  0.725789  0.763434  0.023099  ...  0.428427  0.143373  0.318753
#
#         efdC75    efdC76    efdC77  ratio_NC  ratio_NC_per  ratio_NC_hArea  \
# 0     0.859931  0.382225  0.302311  0.017236      0.115646        0.016730
# 1     0.859539  0.369221  0.299938  0.010656      0.089517        0.010168
# 2     0.861978  0.367980  0.302076  0.007400      0.073961        0.006897
# 3     0.860312  0.382943  0.303682  0.028309      0.154784        0.027752
# 4     0.860292  0.359672  0.300094  0.021569      0.129992        0.020738
# ...        ...       ...       ...       ...           ...             ...
# 3228  0.859606  0.370535  0.299400  0.206211      0.149094        0.085315
# 3229  0.859366  0.375599  0.300755  0.245537      0.247086        0.136756
# 3230  0.860379  0.372458  0.303245  0.191508      0.471092        0.188343
# 3231  0.859608  0.370771  0.299599  0.111823      0.078186        0.023058
# 3232  0.868085  0.362569  0.279162  0.448090      0.346307        0.181780
#
#       nucleus_position
# 0             0.099098
# 1             0.121456
# 2             0.043773
# 3             0.128927
# 4             0.069245
# ...                ...
# 3228          1.943974
# 3229          0.916374
# 3230          0.326252
# 3231          3.177247
# 3232          0.653692
#
# [3233 rows x 200 columns]

# %% [markdown]
# ## Features selection - experiment nº7:  (N+C FROM ALL INCLUDING EFD's)

# %%
features_desc = "From all features select (nuclei + cytoplasms) for binary/ternary/bethesdas classifiers"
N_FEATURES = 30
N_ITER = 10

## Dicts feature importances (stats):
features = functions.list_all_features(20) 
aux = [0.0 for i in features]
features_importance_dict_spfsr_1 = dict(zip(features, aux))
features_importance_dict_spfsr_2 = dict(zip(features, aux))
features_importance_dict_spfsr_3 = dict(zip(features, aux))
features_importance_dict_spfsr_4 = dict(zip(features, aux))

features_importance_dict_mi_1 = dict(zip(features, aux))
features_importance_dict_mi_2 = dict(zip(features, aux))
features_importance_dict_mi_3 = dict(zip(features, aux))
features_importance_dict_mi_4 = dict(zip(features, aux))
start_time = functions.timer()

# %%
len(features)
# Out:
# 200

# %%
# Loop principal:

for it in range(N_ITER):
    print('Iteração número: ', it)

    # Separa dados para treino/validação e teste:
    (X_train, X_test, y_train, y_test, image_cells_ids_train, image_cells_ids_test) = train_test_split(data, target, image_cells_ids, test_size=0.2)

    X_train = X_train[features]

    #### Seleção de características:  classificadores (1, 2, 3, 4)
    best_features_MI_1, feature_importances_MI_1 = functions.features_selection_mi(X_train, y_train['binary'], N_features= N_FEATURES)
    best_features_spfsr_1, feature_importances_spfsr_1 = functions.features_selection_spfsr(X_train, y_train['binary'], N_features= 0)
    best_features_MI_2, feature_importances_MI_2 = functions.features_selection_mi(X_train, y_train['ternary'], N_features= N_FEATURES)
    best_features_spfsr_2, feature_importances_spfsr_2 = functions.features_selection_spfsr(X_train, y_train['ternary'], N_features= 0)
    best_features_MI_3, feature_importances_MI_3 = functions.features_selection_mi(X_train, y_train['bethesda'], N_features= N_FEATURES)
    best_features_spfsr_3, feature_importances_spfsr_3 = functions.features_selection_spfsr(X_train, y_train['bethesda'], N_features= 0)
 
    ### Acumula seleções:   
    features_importance_dict_spfsr_1 = functions.acum_feature_importances(best_features_spfsr_1, feature_importances_spfsr_1, features_importance_dict_spfsr_1)    
    features_importance_dict_spfsr_2 = functions.acum_feature_importances(best_features_spfsr_2, feature_importances_spfsr_2, features_importance_dict_spfsr_2)    
    features_importance_dict_spfsr_3 = functions.acum_feature_importances(best_features_spfsr_3, feature_importances_spfsr_3, features_importance_dict_spfsr_3)    
   
    features_importance_dict_mi_1 = functions.acum_feature_importances(best_features_MI_1, feature_importances_MI_1, features_importance_dict_mi_1)    
    features_importance_dict_mi_2 = functions.acum_feature_importances(best_features_MI_2, feature_importances_MI_2, features_importance_dict_mi_2)    
    features_importance_dict_mi_3 = functions.acum_feature_importances(best_features_MI_3, feature_importances_MI_3, features_importance_dict_mi_3)    
  


functions.timer(start_time)
## Finaliza seleções:
selected_features_spfsr_1, selected_features_scores_spfsr_1 = functions.resume_feature_importance(features_importance_dict_spfsr_1, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_spfsr_2, selected_features_scores_spfsr_2 = functions.resume_feature_importance(features_importance_dict_spfsr_2, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_spfsr_3, selected_features_scores_spfsr_3 = functions.resume_feature_importance(features_importance_dict_spfsr_3, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_spfsr_4, selected_features_scores_spfsr_4 = functions.resume_feature_importance(features_importance_dict_spfsr_4, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_mi_1, selected_features_scores_mi_1 = functions.resume_feature_importance(features_importance_dict_mi_1, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_mi_2, selected_features_scores_mi_2 = functions.resume_feature_importance(features_importance_dict_mi_2, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_mi_3, selected_features_scores_mi_3 = functions.resume_feature_importance(features_importance_dict_mi_3, N_iter=N_ITER, N_features= N_FEATURES)
selected_features_mi_4, selected_features_scores_mi_4 = functions.resume_feature_importance(features_importance_dict_mi_4, N_iter=N_ITER, N_features= N_FEATURES)

## Imprime features selecionadas:
print("1.MI\n",selected_features_mi_1, selected_features_scores_mi_1)
print("2.MI\n",selected_features_mi_2, selected_features_scores_mi_2)
print("3.MI\n",selected_features_mi_3, selected_features_scores_mi_3)
print("4.MI\n",selected_features_mi_4, selected_features_scores_mi_4)

print("1.SPFSR\n",selected_features_spfsr_1, selected_features_scores_spfsr_1)
print("2.SPFSR\n",selected_features_spfsr_2, selected_features_scores_spfsr_2)
print("3.SPFSR\n",selected_features_spfsr_3, selected_features_scores_spfsr_3)
print("4.SPFSR\n",selected_features_spfsr_4, selected_features_scores_spfsr_4)
# Out:
# Iteração número:  0
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.951, st_dev: 0.01, best: 0.951 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.951, st_dev: 0.01, best: 0.951 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 47, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 47, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.31 minutes.
# INFO:SpFSR:SpFSR completed in 1.31 minutes.
# SpFSR-INFO: Best value = 0.962 with 21 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.962 with 21 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 9, value: 0.934, st_dev: 0.011, best: 0.934 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 9, value: 0.934, st_dev: 0.011, best: 0.934 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 50, same feature stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 50, same feature stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 57, same feature stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 57, same feature stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 91, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 91, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.24 minutes.
# INFO:SpFSR:SpFSR completed in 1.24 minutes.
# SpFSR-INFO: Best value = 0.942 with 18 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.942 with 18 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.663, st_dev: 0.014, best: 0.663 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.663, st_dev: 0.014, best: 0.663 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 58, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 58, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.66 minutes.
# INFO:SpFSR:SpFSR completed in 1.66 minutes.
# SpFSR-INFO: Best value = 0.692 with 25 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.692 with 25 features and 100 total iterations.
# Iteração número:  1
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 5, value: 0.955, st_dev: 0.01, best: 0.955 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 5, value: 0.955, st_dev: 0.01, best: 0.955 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 45, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 45, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.25 minutes.
# INFO:SpFSR:SpFSR completed in 1.25 minutes.
# SpFSR-INFO: Best value = 0.961 with 28 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.961 with 28 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 7, value: 0.934, st_dev: 0.005, best: 0.934 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 7, value: 0.934, st_dev: 0.005, best: 0.934 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 87, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 87, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.33 minutes.
# INFO:SpFSR:SpFSR completed in 1.33 minutes.
# SpFSR-INFO: Best value = 0.945 with 28 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.945 with 28 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 5, value: 0.667, st_dev: 0.015, best: 0.667 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 5, value: 0.667, st_dev: 0.015, best: 0.667 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 66, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 66, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.7 minutes.
# INFO:SpFSR:SpFSR completed in 1.7 minutes.
# SpFSR-INFO: Best value = 0.69 with 22 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.69 with 22 features and 100 total iterations.
# Iteração número:  2
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 5, value: 0.949, st_dev: 0.008, best: 0.949 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 5, value: 0.949, st_dev: 0.008, best: 0.949 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 40, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 40, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.31 minutes.
# INFO:SpFSR:SpFSR completed in 1.31 minutes.
# SpFSR-INFO: Best value = 0.957 with 31 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.957 with 31 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 7, value: 0.931, st_dev: 0.01, best: 0.931 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 7, value: 0.931, st_dev: 0.01, best: 0.931 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 52, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 52, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.4 minutes.
# INFO:SpFSR:SpFSR completed in 1.4 minutes.
# SpFSR-INFO: Best value = 0.94 with 29 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.94 with 29 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.672, st_dev: 0.021, best: 0.672 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.672, st_dev: 0.021, best: 0.672 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 69, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 69, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.65 minutes.
# INFO:SpFSR:SpFSR completed in 1.65 minutes.
# SpFSR-INFO: Best value = 0.69 with 26 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.69 with 26 features and 100 total iterations.
# Iteração número:  3
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 4, value: 0.951, st_dev: 0.009, best: 0.951 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 4, value: 0.951, st_dev: 0.009, best: 0.951 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 0, same feature stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 0, same feature stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 47, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 47, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 88, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 88, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.14 minutes.
# INFO:SpFSR:SpFSR completed in 1.14 minutes.
# SpFSR-INFO: Best value = 0.964 with 13 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.964 with 13 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 9, value: 0.937, st_dev: 0.011, best: 0.937 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 9, value: 0.937, st_dev: 0.011, best: 0.937 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 9, same feature stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 9, same feature stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 51, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 51, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 85, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 85, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.27 minutes.
# INFO:SpFSR:SpFSR completed in 1.27 minutes.
# SpFSR-INFO: Best value = 0.943 with 16 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.943 with 16 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.668, st_dev: 0.021, best: 0.668 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.668, st_dev: 0.021, best: 0.668 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 58, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 58, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 92, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 92, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.56 minutes.
# INFO:SpFSR:SpFSR completed in 1.56 minutes.
# SpFSR-INFO: Best value = 0.681 with 21 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.681 with 21 features and 100 total iterations.
# Iteração número:  4
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 7, value: 0.954, st_dev: 0.008, best: 0.954 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 7, value: 0.954, st_dev: 0.008, best: 0.954 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 57, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 57, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 91, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 91, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.12 minutes.
# INFO:SpFSR:SpFSR completed in 1.12 minutes.
# SpFSR-INFO: Best value = 0.958 with 14 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.958 with 14 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 7, value: 0.927, st_dev: 0.01, best: 0.927 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 7, value: 0.927, st_dev: 0.01, best: 0.927 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 55, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 55, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 89, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 89, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.39 minutes.
# INFO:SpFSR:SpFSR completed in 1.39 minutes.
# SpFSR-INFO: Best value = 0.938 with 30 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.938 with 30 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 9, value: 0.665, st_dev: 0.014, best: 0.665 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 9, value: 0.665, st_dev: 0.014, best: 0.665 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 97, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 97, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 2.0 minutes.
# INFO:SpFSR:SpFSR completed in 2.0 minutes.
# SpFSR-INFO: Best value = 0.681 with 37 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.681 with 37 features and 100 total iterations.
# Iteração número:  5
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.951, st_dev: 0.007, best: 0.951 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.951, st_dev: 0.007, best: 0.951 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 52, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 52, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 86, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 86, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.28 minutes.
# INFO:SpFSR:SpFSR completed in 1.28 minutes.
# SpFSR-INFO: Best value = 0.959 with 19 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.959 with 19 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 8, value: 0.934, st_dev: 0.012, best: 0.934 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 8, value: 0.934, st_dev: 0.012, best: 0.934 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 54, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 54, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 88, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 88, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.36 minutes.
# INFO:SpFSR:SpFSR completed in 1.36 minutes.
# SpFSR-INFO: Best value = 0.939 with 14 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.939 with 14 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.665, st_dev: 0.018, best: 0.665 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.665, st_dev: 0.018, best: 0.665 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 44, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 44, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 78, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 78, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.53 minutes.
# INFO:SpFSR:SpFSR completed in 1.53 minutes.
# SpFSR-INFO: Best value = 0.69 with 14 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.69 with 14 features and 100 total iterations.
# Iteração número:  6
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.948, st_dev: 0.009, best: 0.948 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.948, st_dev: 0.009, best: 0.948 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 61, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 61, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.22 minutes.
# INFO:SpFSR:SpFSR completed in 1.22 minutes.
# SpFSR-INFO: Best value = 0.956 with 19 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.956 with 19 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 8, value: 0.93, st_dev: 0.007, best: 0.93 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 8, value: 0.93, st_dev: 0.007, best: 0.93 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 50, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 50, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 84, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 84, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.31 minutes.
# INFO:SpFSR:SpFSR completed in 1.31 minutes.
# SpFSR-INFO: Best value = 0.939 with 11 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.939 with 11 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 5, value: 0.668, st_dev: 0.02, best: 0.668 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 5, value: 0.668, st_dev: 0.02, best: 0.668 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 41, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 41, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 75, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 75, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.59 minutes.
# INFO:SpFSR:SpFSR completed in 1.59 minutes.
# SpFSR-INFO: Best value = 0.685 with 15 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.685 with 15 features and 100 total iterations.
# Iteração número:  7
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 4, value: 0.946, st_dev: 0.007, best: 0.946 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 4, value: 0.946, st_dev: 0.007, best: 0.946 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 36, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 36, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 75, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 75, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.24 minutes.
# INFO:SpFSR:SpFSR completed in 1.24 minutes.
# SpFSR-INFO: Best value = 0.957 with 22 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.957 with 22 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 11, value: 0.932, st_dev: 0.008, best: 0.932 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 11, value: 0.932, st_dev: 0.008, best: 0.932 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 75, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 75, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.45 minutes.
# INFO:SpFSR:SpFSR completed in 1.45 minutes.
# SpFSR-INFO: Best value = 0.941 with 33 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.941 with 33 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.67, st_dev: 0.021, best: 0.67 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.67, st_dev: 0.021, best: 0.67 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 49, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 49, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 83, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 83, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.67 minutes.
# INFO:SpFSR:SpFSR completed in 1.67 minutes.
# SpFSR-INFO: Best value = 0.691 with 23 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.691 with 23 features and 100 total iterations.
# Iteração número:  8
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 6, value: 0.953, st_dev: 0.008, best: 0.953 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 6, value: 0.953, st_dev: 0.008, best: 0.953 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 39, same feature stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 39, same feature stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 73, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 73, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.22 minutes.
# INFO:SpFSR:SpFSR completed in 1.22 minutes.
# SpFSR-INFO: Best value = 0.959 with 22 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.959 with 22 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 9, value: 0.935, st_dev: 0.01, best: 0.935 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 9, value: 0.935, st_dev: 0.01, best: 0.935 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 84, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 84, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.3 minutes.
# INFO:SpFSR:SpFSR completed in 1.3 minutes.
# SpFSR-INFO: Best value = 0.942 with 24 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.942 with 24 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 4, value: 0.663, st_dev: 0.019, best: 0.663 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 4, value: 0.663, st_dev: 0.019, best: 0.663 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 52, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 52, iteration stall limit reached, initializing search...
# SpFSR-INFO: ===> iter_no: 86, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 86, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.65 minutes.
# INFO:SpFSR:SpFSR completed in 1.65 minutes.
# SpFSR-INFO: Best value = 0.691 with 26 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.691 with 26 features and 100 total iterations.
# Iteração número:  9
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 5, value: 0.955, st_dev: 0.01, best: 0.955 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 5, value: 0.955, st_dev: 0.01, best: 0.955 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 45, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 45, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.28 minutes.
# INFO:SpFSR:SpFSR completed in 1.28 minutes.
# SpFSR-INFO: Best value = 0.961 with 28 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.961 with 28 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 7, value: 0.934, st_dev: 0.005, best: 0.934 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 7, value: 0.934, st_dev: 0.005, best: 0.934 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 87, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 87, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.33 minutes.
# INFO:SpFSR:SpFSR completed in 1.33 minutes.
# SpFSR-INFO: Best value = 0.945 with 28 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.945 with 28 features and 100 total iterations.
#
# SpFSR-INFO: Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# INFO:SpFSR:Wrapper: RandomForestClassifier(class_weight='balanced_subsample', n_estimators=5,
#                        random_state=1)
# SpFSR-INFO: Hot start: True
# INFO:SpFSR:Hot start: True
# SpFSR-INFO: Hot start range: 0.2
# INFO:SpFSR:Hot start range: 0.2
# SpFSR-INFO: Feature weighting: False
# INFO:SpFSR:Feature weighting: False
# SpFSR-INFO: Scoring metric: accuracy
# INFO:SpFSR:Scoring metric: accuracy
# SpFSR-INFO: Number of jobs: 4
# INFO:SpFSR:Number of jobs: 4
# SpFSR-INFO: Number of observations in the dataset: 2586
# INFO:SpFSR:Number of observations in the dataset: 2586
# SpFSR-INFO: Number of observations used: 2500
# INFO:SpFSR:Number of observations used: 2500
# SpFSR-INFO: Number of features available: 200
# INFO:SpFSR:Number of features available: 200
# SpFSR-INFO: Number of features to select: 0
# INFO:SpFSR:Number of features to select: 0
# SpFSR-INFO: iter_no: 0, num_ft: 5, value: 0.667, st_dev: 0.015, best: 0.667 @ iter_no 0
# INFO:SpFSR:iter_no: 0, num_ft: 5, value: 0.667, st_dev: 0.015, best: 0.667 @ iter_no 0
# SpFSR-INFO: ===> iter_no: 66, iteration stall limit reached, initializing search...
# INFO:SpFSR:===> iter_no: 66, iteration stall limit reached, initializing search...
# SpFSR-INFO: SpFSR completed in 1.71 minutes.
# INFO:SpFSR:SpFSR completed in 1.71 minutes.
# SpFSR-INFO: Best value = 0.69 with 22 features and 100 total iterations.
#
# INFO:SpFSR:Best value = 0.69 with 22 features and 100 total iterations.
#  Time taken: 0 hours 44 minutes and 26.15 seconds.
# 1.MI
#  ['ratio_NC' 'ratio_NC_per' 'ratio_NC_hArea' 'mrdN' 'eN' 'maxAxN' 'periN'
#  'ardN' 'hAreaN' 'areaN' 'equidiaN' 'fdN' 'compacC' 'circuC' 'riN' 'areaC'
#  'hAreaC' 'maxAxC' 'periC' 'fdC' 'minAxC' 'compacN' 'circuN' 'mrdC'
#  'equidiaC' 'ardC' 'eC' 'riC' 'minAxN' 'convexN'] [0.39624628 0.39498842 0.3908338  0.32254454 0.31822902 0.30615893
#  0.28715804 0.28088877 0.24408115 0.2362197  0.23416209 0.23249336
#  0.22419491 0.22408575 0.21703891 0.20378096 0.18458858 0.18410484
#  0.1821809  0.17900062 0.1784496  0.1763205  0.17621224 0.17555027
#  0.17488043 0.174214   0.17259601 0.1690964  0.14705564 0.04960559]
# 2.MI
#  ['ratio_NC' 'ratio_NC_per' 'ratio_NC_hArea' 'areaC' 'fdC' 'hAreaC'
#  'equidiaC' 'periC' 'maxAxC' 'ardC' 'mrdC' 'eC' 'riC' 'minAxC' 'compacC'
#  'circuC' 'mrdN' 'periN' 'maxAxN' 'eN' 'ardN' 'hAreaN' 'areaN' 'equidiaN'
#  'fdN' 'riN' 'minAxN' 'circuN' 'compacN' 'convexN'] [0.79191124 0.7883939  0.7883257  0.6313914  0.5927327  0.59243464
#  0.5912319  0.58793014 0.5810908  0.5808436  0.56958956 0.5664027
#  0.55239975 0.5521859  0.49839535 0.49834368 0.38373846 0.38263774
#  0.37749597 0.37589675 0.371053   0.3468564  0.34470564 0.34339252
#  0.33167747 0.30981094 0.23724678 0.18161568 0.18159327 0.05570777]
# 3.MI
#  ['ratio_NC' 'ratio_NC_hArea' 'ratio_NC_per' 'areaC' 'periC' 'mrdC'
#  'hAreaC' 'fdC' 'ardC' 'equidiaC' 'maxAxC' 'eC' 'riC' 'compacC' 'circuC'
#  'minAxC' 'mrdN' 'eN' 'periN' 'maxAxN' 'ardN' 'fdN' 'hAreaN' 'equidiaN'
#  'areaN' 'riN' 'minAxN' 'circuN' 'compacN' 'nucleus_position'] [0.8680166  0.8520559  0.8483532  0.6744102  0.6206074  0.6138406
#  0.6131891  0.6099813  0.60945225 0.60918176 0.6038071  0.59423935
#  0.57158893 0.54605573 0.5459266  0.5422527  0.39697534 0.3901636
#  0.38394088 0.37606332 0.37604088 0.345434   0.34177446 0.33160058
#  0.33076555 0.31704023 0.24503928 0.19118968 0.1908722  0.0830247 ]
# 4.MI
#  [] []
# 1.SPFSR
#  ['hAreaN' 'eN' 'ratio_NC_per' 'ardN' 'ratio_NC_hArea' 'solidN' 'compacC'
#  'ratio_NC' 'compacN' 'areaC' 'circuC' 'kN' 'circuN' 'periC' 'efdN50'
#  'efdC69' 'periN' 'eC' 'equidiaN' 'raC' 'maxAxC' 'solidC' 'kC' 'efdC20'
#  'elonC' 'efdN22' 'efdN6' 'efdC9' 'efdC1' 'sdnrlC'] [0.11144678 0.09880449 0.09699471 0.09438305 0.09180647 0.09040274
#  0.08679786 0.08679099 0.07286223 0.07107463 0.07049827 0.0698288
#  0.0650465  0.059177   0.05817742 0.05428595 0.05369958 0.0487887
#  0.04153939 0.03885087 0.03860117 0.03851117 0.03746578 0.03681073
#  0.03627127 0.03352122 0.03306163 0.03228837 0.0315515  0.03054727]
# 2.SPFSR
#  ['solidN' 'ratio_NC_per' 'ratio_NC' 'circuC' 'periN' 'areaN' 'areaC' 'eC'
#  'circuN' 'compacN' 'maxAxC' 'mrdC' 'fdC' 'eN' 'compacC' 'raN' 'equidiaN'
#  'sdnrlN' 'ardN' 'minAxN' 'ratio_NC_hArea' 'efdC12' 'eccenN' 'solidC'
#  'efdN43' 'fdN' 'efdN67' 'efdC58' 'efdC55' 'convexC'] [0.19659607 0.1845378  0.14358896 0.11257637 0.10771579 0.09757332
#  0.09567541 0.09038951 0.07935388 0.07897743 0.0781222  0.07484829
#  0.07409421 0.06515411 0.05633647 0.05057093 0.04434579 0.04371651
#  0.04349761 0.04212951 0.040461   0.03812843 0.03774214 0.03472375
#  0.03399171 0.03322159 0.03178926 0.0317328  0.03010267 0.02961775]
# 3.SPFSR
#  ['ratio_NC_per' 'maxAxC' 'fdN' 'efdC14' 'minAxC' 'ratio_NC_hArea' 'areaC'
#  'solidN' 'ardC' 'solidC' 'kC' 'circuC' 'efdC65' 'fdC' 'efdN14' 'minAxN'
#  'efdC16' 'ratio_NC' 'compacC' 'efdN15' 'mrdC' 'raC' 'eccenN' 'hAreaC'
#  'raN' 'extentN' 'equidiaN' 'extentC' 'elonC' 'riC'] [0.20510535 0.19644572 0.16649754 0.15631793 0.14991626 0.14038636
#  0.13694005 0.1340633  0.12520652 0.12494204 0.11784048 0.11577377
#  0.11408909 0.10196614 0.09872569 0.08796002 0.08567702 0.08310279
#  0.07998738 0.07249375 0.07102442 0.06541315 0.06450756 0.05890139
#  0.05753069 0.0557923  0.05473813 0.05440284 0.05049892 0.04952775]
# 4.SPFSR
#  [] []

# %%
print("1.MI\n",len(selected_features_mi_1), len(selected_features_scores_mi_1))
print("2.MI\n",len(selected_features_mi_2), len(selected_features_scores_mi_2))
print("3.MI\n",len(selected_features_mi_3), len(selected_features_scores_mi_3))
print("4.MI\n",len(selected_features_mi_4), len(selected_features_scores_mi_4))

print("1.SPFSR\n",len(selected_features_spfsr_1), len(selected_features_scores_spfsr_1))
print("2.SPFSR\n",len(selected_features_spfsr_2), len(selected_features_scores_spfsr_2))
print("3.SPFSR\n",len(selected_features_spfsr_3), len(selected_features_scores_spfsr_3))
print("4.SPFSR\n",len(selected_features_spfsr_4), len(selected_features_scores_spfsr_4))
# Out:
# 1.MI
#  30 30
# 2.MI
#  30 30
# 3.MI
#  30 30
# 4.MI
#  0 0
# 1.SPFSR
#  30 30
# 2.SPFSR
#  30 30
# 3.SPFSR
#  30 30
# 4.SPFSR
#  0 0

# %%
## Imprime features selecionadas:
print("1.MI\n",selected_features_mi_1, selected_features_scores_mi_1)
print("2.MI\n",selected_features_mi_2, selected_features_scores_mi_2)
print("3.MI\n",selected_features_mi_3, selected_features_scores_mi_3)
print("4.MI\n",selected_features_mi_4, selected_features_scores_mi_4)

print("1.SPFSR\n",selected_features_spfsr_1, selected_features_scores_spfsr_1)
print("2.SPFSR\n",selected_features_spfsr_2, selected_features_scores_spfsr_2)
print("3.SPFSR\n",selected_features_spfsr_3, selected_features_scores_spfsr_3)
print("4.SPFSR\n",selected_features_spfsr_4, selected_features_scores_spfsr_4)
# Out:
# 1.MI
#  ['ratio_NC' 'ratio_NC_per' 'ratio_NC_hArea' 'mrdN' 'eN' 'maxAxN' 'periN'
#  'ardN' 'hAreaN' 'areaN' 'equidiaN' 'fdN' 'compacC' 'circuC' 'riN' 'areaC'
#  'hAreaC' 'maxAxC' 'periC' 'fdC' 'minAxC' 'compacN' 'circuN' 'mrdC'
#  'equidiaC' 'ardC' 'eC' 'riC' 'minAxN' 'convexN'] [0.39624628 0.39498842 0.3908338  0.32254454 0.31822902 0.30615893
#  0.28715804 0.28088877 0.24408115 0.2362197  0.23416209 0.23249336
#  0.22419491 0.22408575 0.21703891 0.20378096 0.18458858 0.18410484
#  0.1821809  0.17900062 0.1784496  0.1763205  0.17621224 0.17555027
#  0.17488043 0.174214   0.17259601 0.1690964  0.14705564 0.04960559]
# 2.MI
#  ['ratio_NC' 'ratio_NC_per' 'ratio_NC_hArea' 'areaC' 'fdC' 'hAreaC'
#  'equidiaC' 'periC' 'maxAxC' 'ardC' 'mrdC' 'eC' 'riC' 'minAxC' 'compacC'
#  'circuC' 'mrdN' 'periN' 'maxAxN' 'eN' 'ardN' 'hAreaN' 'areaN' 'equidiaN'
#  'fdN' 'riN' 'minAxN' 'circuN' 'compacN' 'convexN'] [0.79191124 0.7883939  0.7883257  0.6313914  0.5927327  0.59243464
#  0.5912319  0.58793014 0.5810908  0.5808436  0.56958956 0.5664027
#  0.55239975 0.5521859  0.49839535 0.49834368 0.38373846 0.38263774
#  0.37749597 0.37589675 0.371053   0.3468564  0.34470564 0.34339252
#  0.33167747 0.30981094 0.23724678 0.18161568 0.18159327 0.05570777]
# 3.MI
#  ['ratio_NC' 'ratio_NC_hArea' 'ratio_NC_per' 'areaC' 'periC' 'mrdC'
#  'hAreaC' 'fdC' 'ardC' 'equidiaC' 'maxAxC' 'eC' 'riC' 'compacC' 'circuC'
#  'minAxC' 'mrdN' 'eN' 'periN' 'maxAxN' 'ardN' 'fdN' 'hAreaN' 'equidiaN'
#  'areaN' 'riN' 'minAxN' 'circuN' 'compacN' 'nucleus_position'] [0.8680166  0.8520559  0.8483532  0.6744102  0.6206074  0.6138406
#  0.6131891  0.6099813  0.60945225 0.60918176 0.6038071  0.59423935
#  0.57158893 0.54605573 0.5459266  0.5422527  0.39697534 0.3901636
#  0.38394088 0.37606332 0.37604088 0.345434   0.34177446 0.33160058
#  0.33076555 0.31704023 0.24503928 0.19118968 0.1908722  0.0830247 ]
# 4.MI
#  [] []
# 1.SPFSR
#  ['hAreaN' 'eN' 'ratio_NC_per' 'ardN' 'ratio_NC_hArea' 'solidN' 'compacC'
#  'ratio_NC' 'compacN' 'areaC' 'circuC' 'kN' 'circuN' 'periC' 'efdN50'
#  'efdC69' 'periN' 'eC' 'equidiaN' 'raC' 'maxAxC' 'solidC' 'kC' 'efdC20'
#  'elonC' 'efdN22' 'efdN6' 'efdC9' 'efdC1' 'sdnrlC'] [0.11144678 0.09880449 0.09699471 0.09438305 0.09180647 0.09040274
#  0.08679786 0.08679099 0.07286223 0.07107463 0.07049827 0.0698288
#  0.0650465  0.059177   0.05817742 0.05428595 0.05369958 0.0487887
#  0.04153939 0.03885087 0.03860117 0.03851117 0.03746578 0.03681073
#  0.03627127 0.03352122 0.03306163 0.03228837 0.0315515  0.03054727]
# 2.SPFSR
#  ['solidN' 'ratio_NC_per' 'ratio_NC' 'circuC' 'periN' 'areaN' 'areaC' 'eC'
#  'circuN' 'compacN' 'maxAxC' 'mrdC' 'fdC' 'eN' 'compacC' 'raN' 'equidiaN'
#  'sdnrlN' 'ardN' 'minAxN' 'ratio_NC_hArea' 'efdC12' 'eccenN' 'solidC'
#  'efdN43' 'fdN' 'efdN67' 'efdC58' 'efdC55' 'convexC'] [0.19659607 0.1845378  0.14358896 0.11257637 0.10771579 0.09757332
#  0.09567541 0.09038951 0.07935388 0.07897743 0.0781222  0.07484829
#  0.07409421 0.06515411 0.05633647 0.05057093 0.04434579 0.04371651
#  0.04349761 0.04212951 0.040461   0.03812843 0.03774214 0.03472375
#  0.03399171 0.03322159 0.03178926 0.0317328  0.03010267 0.02961775]
# 3.SPFSR
#  ['ratio_NC_per' 'maxAxC' 'fdN' 'efdC14' 'minAxC' 'ratio_NC_hArea' 'areaC'
#  'solidN' 'ardC' 'solidC' 'kC' 'circuC' 'efdC65' 'fdC' 'efdN14' 'minAxN'
#  'efdC16' 'ratio_NC' 'compacC' 'efdN15' 'mrdC' 'raC' 'eccenN' 'hAreaC'
#  'raN' 'extentN' 'equidiaN' 'extentC' 'elonC' 'riC'] [0.20510535 0.19644572 0.16649754 0.15631793 0.14991626 0.14038636
#  0.13694005 0.1340633  0.12520652 0.12494204 0.11784048 0.11577377
#  0.11408909 0.10196614 0.09872569 0.08796002 0.08567702 0.08310279
#  0.07998738 0.07249375 0.07102442 0.06541315 0.06450756 0.05890139
#  0.05753069 0.0557923  0.05473813 0.05440284 0.05049892 0.04952775]
# 4.SPFSR
#  [] []

# %%
functions.plot_imp(selected_features_mi_1, selected_features_scores_mi_1, 'Mutual Information - 1.Normal/Anormal', 
         selected_features_spfsr_1, selected_features_scores_spfsr_1, 'Simultaneous Perturbation-FSR - 1.Normal/Anormal') #

# %%
functions.plot_imp(selected_features_mi_2, selected_features_scores_mi_2, 'Mutual Information - 2. Alto/Baixo Grau', 
         selected_features_spfsr_2, selected_features_scores_spfsr_2, 'Simultaneous Perturbation-FSR - 2. Alto/Baixo Grau') #

# %%
functions.plot_imp(selected_features_mi_3, selected_features_scores_mi_3, 'Mutual Information - 3. ASC-US/LSIL', 
         selected_features_spfsr_3, selected_features_scores_spfsr_3, 'Simultaneous Perturbation-FSR - 3. ASC-US/LSIL') #
